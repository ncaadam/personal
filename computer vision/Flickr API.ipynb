# %%
import flickr_api
#import json
import urllib

# %%
#set api key and secret
flickr_api.set_keys(api_key = '78aa598201fe0779491cafac6c036e57', api_secret = '1397b96faca96861')

search_term = 'coca cola'

photos = flickr_api.Photo.search(tags = search_term, media = 'photos')

i = 1

for photo in photos: 
    photo_url = "http://farm"+ str(photo.farm)+".staticflickr.com/" + str(photo.server) + "/" + str(photo.id) + "_" + str(photo.secret) + ".jpg"
    print photo_url
    #urllib.urlretrieve(photo_url,search_term,"photo" + str(i) + ".jpg")
    i += 1
# Out:
# http://farm6.staticflickr.com/5552/14307897426_4f6db6af85.jpg
# http://farm6.staticflickr.com/5557/14144235320_425e84b516.jpg
# http://farm6.staticflickr.com/5522/14328005962_3fca1b4eb1.jpg
# http://farm6.staticflickr.com/5555/14141864327_edbc32ea73.jpg
# http://farm6.staticflickr.com/5476/14348655523_8443e5f71b.jpg
# http://farm3.staticflickr.com/2916/14324824061_e7d902d4a9.jpg
# http://farm6.staticflickr.com/5511/14324772371_c22bd70af5.jpg
# http://farm3.staticflickr.com/2934/14327123534_bddf8e896a.jpg
# http://farm6.staticflickr.com/5565/14304753456_da86accfa6.jpg
# http://farm6.staticflickr.com/5558/14324427934_d4e7d1ef48.jpg
# http://farm3.staticflickr.com/2921/14324249635_e3d444d74d.jpg
# http://farm6.staticflickr.com/5279/14137233819_79d8f8f0c3.jpg
# http://farm6.staticflickr.com/5522/14300537926_c54bac6cea.jpg
# http://farm3.staticflickr.com/2925/14323239735_b5e9fbaff2.jpg
# http://farm3.staticflickr.com/2907/14136099368_9593242772.jpg
# http://farm3.staticflickr.com/2937/14321635084_ee80dbd90c.jpg
# http://farm3.staticflickr.com/2907/14317836781_f9990aafa8.jpg
# http://farm3.staticflickr.com/2911/14134121748_6a197bf45f.jpg
# http://farm3.staticflickr.com/2904/14297428136_b282b36c92.jpg
# http://farm6.staticflickr.com/5552/14316950891_5173f59a64.jpg
# http://farm6.staticflickr.com/5540/14340069743_ae766abcf6.jpg
# http://farm6.staticflickr.com/5510/14133152779_20b63e3009.jpg
# http://farm4.staticflickr.com/3794/14316338541_bcc5e8e3d8.jpg
# http://farm4.staticflickr.com/3795/14295334646_ea72700150.jpg
# http://farm6.staticflickr.com/5556/14317904195_b0b74ae203.jpg
# http://farm6.staticflickr.com/5565/14131287720_cd9f331cd9.jpg
# http://farm4.staticflickr.com/3793/14317905595_8d65415510.jpg
# http://farm3.staticflickr.com/2932/14316508154_16dc42a4ec.jpg
# http://farm3.staticflickr.com/2931/14130236029_13e2093f12.jpg
# http://farm3.staticflickr.com/2909/14130357567_7a36242a06.jpg
# http://farm3.staticflickr.com/2929/14315057522_10d17b3e2f.jpg
# http://farm4.staticflickr.com/3794/14130226598_029a5e2dc6.jpg
# http://farm6.staticflickr.com/5525/14120845580_ae6f2cf27b.jpg
# http://farm4.staticflickr.com/3735/14307493335_8f5d40d26c.jpg
# http://farm4.staticflickr.com/3746/14327641933_94de3e9b1e.jpg
# http://farm4.staticflickr.com/3730/14327634413_cc98fae8c8.jpg
# http://farm3.staticflickr.com/2919/14304124081_fe35c3bdb1.jpg
# http://farm4.staticflickr.com/3671/14120852938_06505510dd.jpg
# http://farm4.staticflickr.com/3753/14120758379_04977a95fc.jpg
# http://farm4.staticflickr.com/3696/14307500535_ff5504a67b.jpg
# http://farm3.staticflickr.com/2923/14305533152_5c20038a28.jpg
# http://farm4.staticflickr.com/3723/14284335256_347f7984de.jpg
# http://farm4.staticflickr.com/3774/14304151811_473dd17ac8.jpg
# http://farm4.staticflickr.com/3811/14284340596_3f6e0af142.jpg
# http://farm3.staticflickr.com/2903/14327637593_be8d54acab.jpg
# http://farm4.staticflickr.com/3767/14304169861_3b56e2588d.jpg
# http://farm4.staticflickr.com/3688/14120896330_96e90fbe96.jpg
# http://farm4.staticflickr.com/3724/14305622632_1eb0bccfaf.jpg
# http://farm4.staticflickr.com/3827/14327649943_5c7b6a418d.jpg
# http://farm3.staticflickr.com/2913/14120820249_0c6afaf260.jpg
# http://farm4.staticflickr.com/3722/14305608512_91646919c8.jpg
# http://farm6.staticflickr.com/5239/14120816750_4128a98768.jpg
# http://farm4.staticflickr.com/3711/14120909197_e43dbc2c98.jpg
# http://farm4.staticflickr.com/3779/14120800698_bc0ae4bbcf.jpg
# http://farm4.staticflickr.com/3724/14306922884_20080e18ee.jpg
# http://farm4.staticflickr.com/3738/14304142711_444a2e5130.jpg
# http://farm4.staticflickr.com/3677/14327656293_29731e1216.jpg
# http://farm6.staticflickr.com/5521/14306881954_9e5aa94fdd.jpg
# http://farm4.staticflickr.com/3821/14120802799_8f34b6834f.jpg
# http://farm3.staticflickr.com/2904/14284349266_4fb8ffc64c.jpg

# %%
for key in photo:
        if key == 'id':
            photo_id = photo_1[key]
        if key == 'farm':
            photo_farm = photo_1[key]
        if key == 'server':
            photo_server = photo_1[key]
        if key == 'secret':
            photo_secret = photo_1[key]
        photo_url = "http://farm"+ str(photo_farm)+".staticflickr.com/" + str(photo_server) + "/" + str(photo_id) + "_" + str(photo_secret) + ".jpg"
        print photo_url
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d7bdfa16e4a7> in <module>()
# ----> 1 for key in photo:
#       2         if key == 'id':
#       3             photo_id = photo_1[key]
#       4         if key == 'farm':
#       5             photo_farm = photo_1[key]
#
# /home/ncaadam/.local/lib/python2.7/site-packages/flickr_api-0.5dev-py2.7.egg/flickr_api/objects.pyc in __getitem__(self, key)
#     106
#     107     def __getitem__(self, key):
# --> 108         return self.__dict__[key]
#     109
#     110     def __setitem__(self, key, value):
#
# KeyError: 0
