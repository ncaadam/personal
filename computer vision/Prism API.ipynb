# %%
from urllib2 import Request, urlopen, URLError
import requests
import json

# %%
base_url = "https://api.prism.com/v1/accounts/1944/"
headers = {'Authorization': 'Token 26699eee8ed9e499421e66095d9db8b3f1d8a46a'}
r = requests.get(base_url, headers=headers)

# %%
"https://api.prism.com/v1/accounts/471/sites/505/data/count/aggregation/?type=entry&start=2014-10-10&stop=2014-10-30&period=day&aggregations=sum"
# Out:
# 'https://api.prism.com/v1/accounts/471/sites/505/data/count/aggregation/?type=entry&start=2014-10-10&stop=2014-10-30&period=day&aggregations=sum'

# %%
param_input = "sites"
if r.ok:
    output = r.json()
    for key,value in output.iteritems():
        if key == param_input + "_url":
            new_r = requests.get(value, headers=headers)
            if new_r.ok:
                new_output = new_r.json()
                if len(new_output) > 0:
                    print "There are", str(len(new_output)), "resource(s) in response."
                    for line in new_output:
                        if line["name"] == "Hallandale":
                            newest_r = requests.get(line["url"], headers = headers)
                            hall_json = newest_r.json()
                            #for key,value in line.iteritems():
                            #    print key + ":",value
                            #if key == "default_lens" and value is not None:
                            #    params = {}
                            #    for key2,value2 in value.iteritems():
                            #        if key2 == "instances_url":
                            #            instances_url = value2
                            #        elif key2 == "earliest_at":
                            #            params["start"] = value2
                            #        elif key2 == "latest_at":
                            #            params["stop"] = value2
                                
                            #    newest_r = requests.get(instances_url, headers=headers,params = params)
                            #    if newest_r.ok:
                            #        print newest_r.json()
                            #    else:
                            #        print newest_r.reason
                else:
                    print new_r.request.path_url, "is empty!"
            else:
                print r.reason, "-", r.url
else:
    print r.reason, "-", r.url
# Out:
# There are 2 resource(s) in response.

# %%
tripwire_json = requests.get(hall_json['tripwires_url'],headers = headers).json()

# %%
tripwire_json[1]
# Out:
# {u'camera_id': 76433,
#  u'camera_url': u'https://api.prism.com/v1/accounts/1944/cameras/76433/',
#  u'id': 3702,
#  u'name': u'Cafe Entry 2',
#  u'timezone': u'US/Eastern',
#  u'tripwire_type': {u'id': 626,
#   u'name': u'entry',
#   u'tripwires_url': u'https://api.prism.com/v1/accounts/1944/tripwires/?tripwire_type=626',
#   u'url': u'https://api.prism.com/v1/accounts/1944/tripwire-types/626/'},
#  u'url': u'https://api.prism.com/v1/accounts/1944/tripwires/3702/'}

# %%
trip_data_r = requests.get(tripwire_json['tripwires_url'])
# Out:
# {u'camera_url': u'https://api.prism.com/v1/accounts/1944/cameras/76433/', u'tripwire_type': {u'url': u'https://api.prism.com/v1/accounts/1944/tripwire-types/626/', u'id': 626, u'tripwires_url': u'https://api.prism.com/v1/accounts/1944/tripwires/?tripwire_type=626', u'name': u'entry'}, u'name': u'Cafe Entry 1', u'url': u'https://api.prism.com/v1/accounts/1944/tripwires/3346/', u'camera_id': 76433, u'timezone': u'US/Eastern', u'id': 3346}
# {u'camera_url': u'https://api.prism.com/v1/accounts/1944/cameras/76433/', u'tripwire_type': {u'url': u'https://api.prism.com/v1/accounts/1944/tripwire-types/626/', u'id': 626, u'tripwires_url': u'https://api.prism.com/v1/accounts/1944/tripwires/?tripwire_type=626', u'name': u'entry'}, u'name': u'Cafe Entry 2', u'url': u'https://api.prism.com/v1/accounts/1944/tripwires/3702/', u'camera_id': 76433, u'timezone': u'US/Eastern', u'id': 3702}
# ...

# %%
params = {'type':'entry','start':'2014-10-14','stop':'2014-10-31','period':'hour','aggregations':'min,max,sum'}
data_r = requests.get(hall_json['url']+"data/activity/aggregation/",headers = headers, params = params)

# %%
data_r.json()
# Out:
# [{u'datetime': u'2014-10-14T00:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T01:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T02:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T03:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T04:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T05:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T06:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T07:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T08:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
#  {u'datetime': u'2014-10-14T09:00:00Z',
#   u'max': None,
#   u'min': None,
#   u'sum': None},
# ...
