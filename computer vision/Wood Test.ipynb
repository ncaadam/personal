# %%
from SimpleCV import *
disp = Display(displaytype='notebook')

# %% [markdown]
# dry
# encased
# decayed
# edge
# encased
# horn
# leaf
# sound

# %%
img = Image("./wood/wood/st1014")
img.save(disp)

# %%
roi = ROI(122,147,207,182)
crop = img.crop(roi)
crop.save(disp)

# %%
hue_dist = img.hueDistance()
hue_dist.save(disp)

# %%
wshed = img.watershed()
wshed.save(disp)

# %%
img.clearLayers()
blobs = img.findBlobsFromWatershed(wshed)
new_img = blobs[-1].mImg.invert()
new_img.save(disp)
blobs = new_img.findBlobs()
blobs.draw(width=-1)
new_img.save(disp)
