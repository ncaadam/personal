# %%
from SimpleCV import *

# %%
disp = Display()
cam = Camera()
done = False
while not disp.isDone():
    cam.getImage().save(disp)
    time.sleep(.01)
    if disp.mouseLeft:
        disp.done = True
