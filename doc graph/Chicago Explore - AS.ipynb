# %%
import pandas as pd
import numpy as np
from pyspark import SparkContext, SparkConf
import graphlab as gl
import blaze as b
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-13367 - Server binary: /home/ncaadam/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1421184804.log
# [INFO] GraphLab Server Version: 1.2.1

# %%
# Configure Spark Settings
conf=SparkConf()
conf.set("spark.executor.memory", "1g")
conf.set("spark.cores.max", "4")
#conf.set("spark.driver.extraClassPath", gl.get_spark_integration_jar_path())
conf.setAppName("My App")

## Initialize SparkContext
sc = SparkContext('local[*]', conf=conf)

# %%
def safe_cast(val, to_type, default=0):
    try:
        return to_type(val)
    except ValueError:
        return default

# %%
def chicago_filter(line):
    five_zip = safe_cast(line[10][0:6].replace('\"',''), int)
    if five_zip in chi_zip_list:
        return True
    else:
        return False

# %%
def quote_filter(line):
    new_line = []
    for cell in line:
        new_line.append(cell.replace('\"',''))
    return new_line

# %%
# create chicago zip list
chicago_zips = pd.read_csv('data/chicago_metro_zip.csv')
zip_only = chicago_zips['zip']
chi_zip_list = zip_only.tolist()

# %%
docgraph_node_raw = sc.textFile('../../../DocGraph/data/DocGraph-Procedure-2012-Public-Domain/DocGraph_Procedure.csv').map(lambda x: x.split('\t'))

# %%
header = docgraph_node_raw.first()
docgraph_node_raw = docgraph_node_raw.filter(lambda line: line != header)

# %%
docgraph_node_updated = docgraph_node_raw.map(lambda x : quote_filter(x))

# %%
docgraph_node_chicago = docgraph_node_updated.filter(lambda line: chicago_filter(line))

# %%
docgraph_node_chicago = gl.SFrame.from_rdd(docgraph_node_chicago)

# %%
col_names = {'X1':'npi','X2':'nppes_provider_last_org_name','X3':'nppes_provider_first_name','X4':'nppes_provider_mi',
             'X5':'nppes_credentials','X6':'nppes_provider_gender','X7':'nppes_entity_code','X8':'nppes_provider_street1',
             'X9':'nppes_provider_street2','X10':'nppes_provider_city','X11':'nppes_provider_zip',
             'X12':'nppes_provider_state','X13':'nppes_provider_country','X14':'provider_type',
             'X15':'medicare_participation_indicator','X16':'place_of_Service','X17':'hcpcs_code','X18':'line_srvc_cnt',
             'X19':'bene_unique_cnt','X20':'bene_day_srvc_cnt','X21':'average_Medicare_allowed_amt',
             'X22':'stdev_Medicare_allowed_amt','X23':'average_submitted_chrg_amt','X24':'stdev_submitted_chrg_amt',
             'X25':'average_Medicare_payment_amt','X26':'stdev_Medicare_payment_amt'}
docgraph_node_chicago.rename(col_names)
# Out:
# Columns:
# 	npi	str
# 	nppes_provider_last_org_name	str
# 	nppes_provider_first_name	str
# 	nppes_provider_mi	str
# 	nppes_credentials	str
# 	nppes_provider_gender	str
# 	nppes_entity_code	str
# 	nppes_provider_street1	str
# 	nppes_provider_street2	str
# 	nppes_provider_city	str
# 	nppes_provider_zip	str
# 	nppes_provider_state	str
# 	nppes_provider_country	str
# 	provider_type	str
# 	medicare_participation_indicator	str
# 	place_of_Service	str
# 	hcpcs_code	str
# 	line_srvc_cnt	str
# 	bene_unique_cnt	str
# 	bene_day_srvc_cnt	str
# 	average_Medicare_allowed_amt	str
# 	stdev_Medicare_allowed_amt	str
# 	average_submitted_chrg_amt	str
# 	stdev_submitted_chrg_amt	str
# 	average_Medicare_payment_amt	str
# 	stdev_Medicare_payment_amt	str
#
# Rows: 36403
#
# Data:
# +------------+------------------------------+---------------------------+-------------------+
# |    npi     | nppes_provider_last_org_name | nppes_provider_first_name | nppes_provider_mi |
# +------------+------------------------------+---------------------------+-------------------+
# | 1003005430 |           BEAUMONT           |           LAURA           |         A         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# | 1003016270 |        MUTHUKRISHNAN         |           VIJAI           |         B         |
# +------------+------------------------------+---------------------------+-------------------+
# +-------------------+-----------------------+-------------------+
# | nppes_credentials | nppes_provider_gender | nppes_entity_code |
# +-------------------+-----------------------+-------------------+
# |        PSYD       |           F           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# |        M.D.       |           M           |         I         |
# +-------------------+-----------------------+-------------------+
# +-------------------------+------------------------+---------------------+
# |  nppes_provider_street1 | nppes_provider_street2 | nppes_provider_city |
# +-------------------------+------------------------+---------------------+
# | 11801 SOUTHWEST HIGHWAY |      STE 3 SOUTH       |    PALOS HEIGHTS    |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# |      25 COLLINS RD      |                        |       BRISTOL       |
# +-------------------------+------------------------+---------------------+
# +--------------------+----------------------+------------------------+
# | nppes_provider_zip | nppes_provider_state | nppes_provider_country |
# +--------------------+----------------------+------------------------+
# |       60463        |          IL          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# |     060103893      |          CT          |           US           |
# +--------------------+----------------------+------------------------+
# +-----------------------+--------------------------------+------------------+
# |     provider_type     | medicare_participation_ind ... | place_of_Service |
# +-----------------------+--------------------------------+------------------+
# | Clinical Psychologist |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# |    Family Practice    |               Y                |        O         |
# +-----------------------+--------------------------------+------------------+
# +------------+---------------+-----------------+-------------------+-----+
# | hcpcs_code | line_srvc_cnt | bene_unique_cnt | bene_day_srvc_cnt | ... |
# +------------+---------------+-----------------+-------------------+-----+
# |   90806    |       73      |        12       |         73        | ... |
# |   36415    |       92      |        69       |         92        | ... |
# |   80053    |       62      |        52       |         62        | ... |
# |   80061    |       43      |        32       |         43        | ... |
# |   81002    |       21      |        18       |         21        | ... |
# |   82947    |       18      |        11       |         18        | ... |
# |   83036    |       16      |        13       |         16        | ... |
# |   84443    |       22      |        21       |         22        | ... |
# |   85025    |       57      |        50       |         57        | ... |
# |   93000    |       30      |        29       |         30        | ... |
# |    ...     |      ...      |       ...       |        ...        | ... |
# +------------+---------------+-----------------+-------------------+-----+
# [36403 rows x 26 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
#docgraph_node_chicago['npi'][0:1][0][len(docgraph_node_chicago['npi'][0:1][0])-1]

# %%
col_types = {'line_srvc_cnt':int,'bene_unique_cnt':int,'bene_day_srvc_cnt':int,'average_Medicare_allowed_amt':float,
             'stdev_Medicare_allowed_amt':float,'average_submitted_chrg_amt':float,'stdev_submitted_chrg_amt':float,
             'average_Medicare_payment_amt':float,'stdev_Medicare_payment_amt':float}

# %%
for name in docgraph_node_chicago.column_names():
    if name in col_types.keys():
        if col_types[name] is int:
            docgraph_node_chicago[name] = docgraph_node_chicago[name].astype(int)
        elif col_types[name] is float:
            docgraph_node_chicago[name] = docgraph_node_chicago[name].astype(float)
        else:
            print 'shit'
        #execute = 'docgraph_node_chicago[name] = docgraph_node_chicago[name].astype(col_types[name])'
        #docgraph_node_chicago[name] = docgraph_node_chicago[name].astype(string)

# %%
docgraph_node_chicago.dtype()
# Out:
# [str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  int,
#  int,
#  int,
#  float,
#  float,
#  float,
#  float,
#  float,
#  float]

# %%
docgraph_node_chicago.show()

# %%
docgraph_edge_raw = sc.textFile('../../../DocGraph/data/DocGraph-2012-2013-Days365-Edge-Public-Domain/DocGraph-2012-2013-Days365.csv').map(lambda x: x.split('\t'))

# %%
chi_npi_list = list(docgraph_node_chicago['npi'].unique())

# %%
def filter_npis(line):
    if line[0] in chi_npi_list and line[1] in chi_npi_list:
        return True
    else:
        return False

# %%
docgraph_edge_chicago = docgraph_edge_raw.filter(lambda line : filter_npis(line))

# %%
docgraph_edge_raw.count()
# Out:
# 154568917

# %%
docgraph_edge_chicago.first()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-99-0652b66df78b> in <module>()
# ----> 1 docgraph_edge_chicago.first()
#
# /home/ncaadam/spark-1.1.0/python/pyspark/rdd.pyc in first(self)
#    1165         2
#    1166         """
# -> 1167         return self.take(1)[0]
#    1168
#    1169     def saveAsNewAPIHadoopDataset(self, conf, keyConverter=None, valueConverter=None):
#
# /home/ncaadam/spark-1.1.0/python/pyspark/rdd.pyc in take(self, num)
#    1151             p = range(
#    1152                 partsScanned, min(partsScanned + numPartsToTry, totalParts))
# -> 1153             res = self.context.runJob(self, takeUpToNumLeft, p, True)
#    1154
#    1155             items += res
#
# /home/ncaadam/spark-1.1.0/python/pyspark/context.pyc in runJob(self, rdd, partitionFunc, partitions, allowLocal)
#     768         # SparkContext#runJob.
#     769         mappedRDD = rdd.mapPartitions(partitionFunc)
# --> 770         it = self._jvm.PythonRDD.runJob(self._jsc.sc(), mappedRDD._jrdd, javaPartitions, allowLocal)
#     771         return list(mappedRDD._collect_iterator_through_file(it))
#     772
#
# /home/ncaadam/anaconda/lib/python2.7/site-packages/py4j/java_gateway.pyc in __call__(self, *args)
#     536         answer = self.gateway_client.send_command(command)
#     537         return_value = get_return_value(answer, self.gateway_client,
# --> 538                 self.target_id, self.name)
#     539
#     540         for temp_arg in temp_args:
#
# /home/ncaadam/anaconda/lib/python2.7/site-packages/py4j/protocol.pyc in get_return_value(answer, gateway_client, target_id, name)
#     298                 raise Py4JJavaError(
#     299                     'An error occurred while calling {0}{1}{2}.\n'.
# --> 300                     format(target_id, '.', name), value)
#     301             else:
#     302                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.runJob.
# : org.apache.spark.SparkException: Job 24 cancelled because Stage 24 was cancelled
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1185)
# 	at org.apache.spark.scheduler.DAGScheduler.handleJobCancellation(DAGScheduler.scala:1155)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleStageCancellation$1.apply$mcVI$sp(DAGScheduler.scala:1143)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleStageCancellation$1.apply(DAGScheduler.scala:1142)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleStageCancellation$1.apply(DAGScheduler.scala:1142)
# 	at scala.collection.IndexedSeqOptimized$class.foreach(IndexedSeqOptimized.scala:33)
# 	at scala.collection.mutable.ArrayOps$ofInt.foreach(ArrayOps.scala:156)
# 	at org.apache.spark.scheduler.DAGScheduler.handleStageCancellation(DAGScheduler.scala:1142)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessActor$$anonfun$receive$2.applyOrElse(DAGScheduler.scala:1364)
# 	at akka.actor.ActorCell.receiveMessage(ActorCell.scala:498)
# 	at akka.actor.ActorCell.invoke(ActorCell.scala:456)
# 	at akka.dispatch.Mailbox.processMailbox(Mailbox.scala:237)
# 	at akka.dispatch.Mailbox.run(Mailbox.scala:219)
# 	at akka.dispatch.ForkJoinExecutorConfigurator$AkkaForkJoinTask.exec(AbstractDispatcher.scala:386)
# 	at scala.concurrent.forkjoin.ForkJoinTask.doExec(ForkJoinTask.java:260)
# 	at scala.concurrent.forkjoin.ForkJoinPool$WorkQueue.runTask(ForkJoinPool.java:1339)
# 	at scala.concurrent.forkjoin.ForkJoinPool.runWorker(ForkJoinPool.java:1979)
# 	at scala.concurrent.forkjoin.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:107)
